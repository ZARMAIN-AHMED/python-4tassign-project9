# %% [markdown]
# <a href="https://colab.research.google.com/github/ZARMAIN-AHMED/python-4tassign-project9/blob/main/hangman.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random


import string

words = [
    'python', 'programming', 'computer', 'algorithm', 'database',
    'network', 'software', 'hardware', 'internet', 'developer',
    'coding', 'application', 'system', 'interface', 'function',
    'variable', 'class', 'object', 'method', 'library',
    'framework', 'server', 'client', 'data', 'code',
    'file', 'directory', 'path', 'error', 'debug',
    'test', 'build', 'deploy', 'version', 'control',
    'repository', 'commit', 'branch', 'merge', 'push',
    'pull', 'clone', 'fork', 'issue', 'pull request'
]

def get_valid_word(words):
    word = random.choice(words)
    while '-' in word or ' ' in word:
        word = random.choice(words)

    return word.upper()


def hangman():
    word = get_valid_word(words)
    word_letters = set(word)
    alphabet = set(string.ascii_uppercase)
    used_letters = set()

    lives = 7

    # getting user input
    while len(word_letters) > 0 and lives > 0:

        print('You have', lives, 'lives left and you have used these letters: ', ' '.join(used_letters))


        word_list = [letter if letter in used_letters else '-' for letter in word]
        print([lives])
        print('Current word: ', ' '.join(word_list))

        user_letter = input('Guess a letter: ').upper()
        if user_letter in alphabet - used_letters:
            used_letters.add(user_letter)
            if user_letter in word_letters:
                word_letters.remove(user_letter)
                print('')

            else:
                lives = lives - 1
                print('\nYour letter,', user_letter, 'is not in the word.')

        elif user_letter in used_letters:
            print('\nYou have already used that letter. Guess another letter.')

        else:
            print('\nThat is not a valid letter.')


    if lives == 0:
        print([lives])
        print('You died, sorry. The word was', word)
    else:
        print('YAY! You guessed the word', word, '!!')


if __name__ == '__main__':
    hangman()
# Out:
# You have 7 lives left and you have used these letters:
# [7]
# Current word:  - - - - - - - - - - -
# Guess a letter: 9
#
# That is not a valid letter.
# You have 7 lives left and you have used these letters:
# [7]
# Current word:  - - - - - - - - - - -
# Guess a letter: j
#
# Your letter, J is not in the word.
# You have 6 lives left and you have used these letters:  J
# [6]
# Current word:  - - - - - - - - - - -
# Guess a letter: k
#
# Your letter, K is not in the word.
# You have 5 lives left and you have used these letters:  J K
# [5]
# Current word:  - - - - - - - - - - -
# Guess a letter: l
#
# Your letter, L is not in the word.
# You have 4 lives left and you have used these letters:  L J K
# [4]
# Current word:  - - - - - - - - - - -
# Guess a letter: j
#
# You have already used that letter. Guess another letter.
# You have 4 lives left and you have used these letters:  L J K
# [4]
# Current word:  - - - - - - - - - - -
# Guess a letter: u
#
# Your letter, U is not in the word.
# You have 3 lives left and you have used these letters:  U L J K
# [3]
# Current word:  - - - - - - - - - - -
# Guess a letter: o
#
# You have 3 lives left and you have used these letters:  L O K U J
# [3]
# Current word:  - - O - - - - - - - -
# Guess a letter: b'
#
# That is not a valid letter.
# You have 3 lives left and you have used these letters:  L O K U J
# [3]
# Current word:  - - O - - - - - - - -
# Guess a letter: a
#
# You have 3 lives left and you have used these letters:  L O K A U J
# [3]
# Current word:  - - O - - A - - - - -
# Guess a letter:
#
# That is not a valid letter.
# You have 3 lives left and you have used these letters:  L O K A U J
# [3]
# Current word:  - - O - - A - - - - -
# Guess a letter: w
#
# Your letter, W is not in the word.
# You have 2 lives left and you have used these letters:  L O W K A U J
# [2]
# Current word:  - - O - - A - - - - -
# Guess a letter: w
#
# You have already used that letter. Guess another letter.
# You have 2 lives left and you have used these letters:  L O W K A U J
# [2]
# Current word:  - - O - - A - - - - -
# Guess a letter: q
#
# Your letter, Q is not in the word.
# You have 1 lives left and you have used these letters:  L O W K A Q U J
# [1]
# Current word:  - - O - - A - - - - -
# Guess a letter: w
#
# You have already used that letter. Guess another letter.
# You have 1 lives left and you have used these letters:  L O W K A Q U J
# [1]
# Current word:  - - O - - A - - - - -
# Guess a letter: i
#
# You have 1 lives left and you have used these letters:  L O W K A Q I U J
# [1]
# Current word:  - - O - - A - - I - -
# Guess a letter: o
#
# You have already used that letter. Guess another letter.
# You have 1 lives left and you have used these letters:  L O W K A Q I U J
# [1]
# Current word:  - - O - - A - - I - -
# Guess a letter: j
#
# You have already used that letter. Guess another letter.
# You have 1 lives left and you have used these letters:  L O W K A Q I U J
# [1]
# Current word:  - - O - - A - - I - -
# Guess a letter: k
#
# You have already used that letter. Guess another letter.
# You have 1 lives left and you have used these letters:  L O W K A Q I U J
# [1]
# Current word:  - - O - - A - - I - -
# Guess a letter: k
#
# You have already used that letter. Guess another letter.
# You have 1 lives left and you have used these letters:  L O W K A Q I U J
# [1]
# Current word:  - - O - - A - - I - -
# Guess a letter: g
#
# You have 1 lives left and you have used these letters:  L O W G K A Q I U J
# [1]
# Current word:  - - O G - A - - I - G
# Guess a letter: v
#
# Your letter, V is not in the word.
# [0]
# You died, sorry. The word was PROGRAMMING
